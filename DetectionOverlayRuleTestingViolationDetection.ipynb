# %%
# !pip install ultralytics opencv-python torch torchvision torchaudio numpy
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.222-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.25.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Downloading ultralytics-8.3.222-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.2 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.222 ultralytics-thop-2.0.18

# %%
import cv2
import torch
from ultralytics import YOLO
# Load model
model_path = "/content/drive/MyDrive/Project/Dataset/css-data/cross_validation/results_fold3/weights/best.pt"
model = YOLO(model_path)
# Detection parameters
conf_thres = 0.5
iou_thres = 0.45
imgsz = 640
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
import torch
print(torch.cuda.is_available())
# Out:
# False

# %%
import glob
import os

# Base dataset path
base_dir = "/content/drive/MyDrive/Project/Dataset"

# Search for common video formats recursively
video_extensions = ["*.mp4", "*.avi", "*.mov", "*.mkv"]
video_files = []
for ext in video_extensions:
    video_files.extend(glob.glob(os.path.join(base_dir, "**", ext), recursive=True))

# Display found videos
print("Found video files:")
for v in video_files:
    print(v)

print(f"\nTotal videos found: {len(video_files)}")
# Out:
# 🎥 Found video files:
# /content/drive/MyDrive/Project/Dataset/source_files/source_files/hardhat.mp4
# /content/drive/MyDrive/Project/Dataset/source_files/source_files/JapanPPE.mp4
# /content/drive/MyDrive/Project/Dataset/source_files/source_files/indianworkers.mp4
# /content/drive/MyDrive/Project/Dataset/yolov8_ppe_detection/visual_demo/videos/hardhat.mp4
# /content/drive/MyDrive/Project/Dataset/yolov8_ppe_detection/visual_demo/videos/indianworkers.mp4
# /content/drive/MyDrive/Project/Dataset/yolov8_ppe_detection/visual_demo/outputs/detections_videos/hardhat.avi
# /content/drive/MyDrive/Project/Dataset/yolov8_ppe_detection/visual_demo/outputs/detections_videos/indianworkers.avi
# /content/drive/MyDrive/Project/Dataset/yolov8_ppe_detection/visual_demo/outputs/detections_videos2/indianworkers.avi
#
# ✅ Total videos found: 8

# %%
import cv2

video_path = "/content/drive/MyDrive/Project/Dataset/source_files/source_files/JapanPPE.mp4"
output_path = "/content/drive/MyDrive/Project/Dataset/yolov8_ppe_detection/visual_demo/outputs"

cap = cv2.VideoCapture(video_path)
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, 20.0,
                      (int(cap.get(3)), int(cap.get(4))))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = model.predict(source=frame, conf=conf_thres, iou=iou_thres, imgsz=imgsz, device=device, verbose=False)
    annotated_frame = results[0].plot()
    out.write(annotated_frame)

cap.release()
out.release()

print(f"🎥 Detection video saved at: {output_path}")
# Out:
# 🎥 Detection video saved at: /content/drive/MyDrive/Project/Dataset/yolov8_ppe_detection/visual_demo/outputs

# %%
import cv2
import os
import numpy as np
import pandas as pd
from PIL import Image, ImageDraw, ImageFont
from ultralytics import YOLO
from datetime import datetime
import matplotlib.pyplot as plt

# === CONFIG ===
VIDEO_PATH = "/content/drive/MyDrive/Project/Dataset/yolov8_ppe_detection/visual_demo/videos/indianworkers.mp4"  # 👈 Change this
OUTPUT_DIR = "/content/drive/MyDrive/Project/Dataset/yolov8_ppe_detection/visual_demo/outputs"

MODEL_PATH = "/content/drive/MyDrive/Project/Dataset/css-data/cross_validation/results_fold3/weights/best.pt"

os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(os.path.join(OUTPUT_DIR, "logs"), exist_ok=True)

OUTPUT_VIDEO = os.path.join(OUTPUT_DIR, "annotated_output.mp4")
LOG_CSV = os.path.join(OUTPUT_DIR, "logs/violations_log.csv")

CONF_THRES = 0.4
IOU_THRES = 0.45
DEVICE = "cpu"  # or 'cuda' if GPU is available

# === MODEL LOAD ===
model = YOLO(MODEL_PATH)
print(f"✅ Model loaded from: {MODEL_PATH}")

# === COLOR CODING ===
VIOLATION_CLASSES = ["NO-Hardhat", "NO-Mask", "NO-Safety Vest"]
SAFE_COLOR = (0, 255, 0)   # Green
VIOL_COLOR = (255, 0, 0)   # Red

# === LOG INITIALIZATION ===
violations_list = []

# === UTILS ===
def draw_boxes(image, detections):
    draw = ImageDraw.Draw(image)
    for det in detections:
        label = det["label"]
        conf = det["conf"]
        box = det["box"]

        color = VIOL_COLOR if label in VIOLATION_CLASSES else SAFE_COLOR
        draw.rectangle(box, outline=color, width=3)
        draw.text((box[0]+5, box[1]-15), f"{label} {conf:.2f}", fill=color)
    return image


def log_violations(detections, timestamp):
    for det in detections:
        if det["label"] in VIOLATION_CLASSES:
            violations_list.append({
                "Timestamp": timestamp,
                "Violation": det["label"],
                "Confidence": round(det["conf"], 3)
            })


def results_to_list(result, class_names):
    """Convert YOLO result to a list of detections"""
    dets = []
    for box in result.boxes:
        cls_id = int(box.cls[0])
        dets.append({
            "label": class_names[cls_id],
            "conf": float(box.conf[0]),
            "box": [int(x) for x in box.xyxy[0].tolist()]
        })
    return dets


# === VIDEO PROCESSING ===
cap = cv2.VideoCapture(VIDEO_PATH)
if not cap.isOpened():
    raise FileNotFoundError(f"❌ Could not open video: {VIDEO_PATH}")

fps = int(cap.get(cv2.CAP_PROP_FPS))
w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(OUTPUT_VIDEO, fourcc, fps, (w, h))

frame_count = 0

print(f"🎥 Processing video: {VIDEO_PATH}")
print(f"Resolution: {w}x{h}, FPS: {fps}")

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame_count += 1
    timestamp = datetime.now().strftime("%H:%M:%S")

    results = model.predict(frame, conf=CONF_THRES, iou=IOU_THRES, device=DEVICE, verbose=False)
    dets = results_to_list(results[0], model.names)

    # Log and draw
    log_violations(dets, timestamp)
    frame_pil = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    annotated_pil = draw_boxes(frame_pil, dets)
    frame_bgr = cv2.cvtColor(np.array(annotated_pil), cv2.COLOR_RGB2BGR)
    out.write(frame_bgr)

    if frame_count % 50 == 0:
        print(f"Processed {frame_count} frames...")

cap.release()
out.release()

print(f"\n✅ Annotated video saved: {OUTPUT_VIDEO}")

# === SAVE VIOLATION LOG ===
if violations_list:
    df = pd.DataFrame(violations_list)
    df.to_csv(LOG_CSV, index=False)
    print(f"📜 Violation log saved: {LOG_CSV}")
else:
    print("✅ No violations detected!")

# === SUMMARY BAR CHART ===
if len(violations_list) > 0:
    summary = pd.Series([v["Violation"] for v in violations_list]).value_counts()
    plt.figure(figsize=(7, 4))
    summary.plot(kind="bar", color="crimson")
    plt.title("Total Violations Detected per Class")
    plt.ylabel("Count")
    plt.xticks(rotation=30)
    plt.tight_layout()

    summary_path = os.path.join(OUTPUT_DIR, "logs/violation_summary.png")
    plt.savefig(summary_path)
    plt.show()

    print(f"📊 Summary chart saved: {summary_path}")
else:
    print("No violations to summarize.")
# Out:
# ✅ Model loaded from: /content/drive/MyDrive/Project/Dataset/css-data/cross_validation/results_fold3/weights/best.pt
# 🎥 Processing video: /content/drive/MyDrive/Project/Dataset/yolov8_ppe_detection/visual_demo/videos/indianworkers.mp4
# Resolution: 1280x720, FPS: 29
# Processed 50 frames...
# Processed 100 frames...
# Processed 150 frames...
# Processed 200 frames...
# Processed 250 frames...
# Processed 300 frames...
# Processed 350 frames...
# Processed 400 frames...
# Processed 450 frames...
# Processed 500 frames...
# Processed 550 frames...
# Processed 600 frames...
#
# ✅ Annotated video saved: /content/drive/MyDrive/Project/Dataset/yolov8_ppe_detection/visual_demo/outputs/annotated_output.mp4
# 📜 Violation log saved: /content/drive/MyDrive/Project/Dataset/yolov8_ppe_detection/visual_demo/outputs/logs/violations_log.csv
# 📊 Summary chart saved: /content/drive/MyDrive/Project/Dataset/yolov8_ppe_detection/visual_demo/outputs/logs/violation_summary.png

# %%
import os
import shutil
import glob

# Define paths
src_folder = "/content/drive/MyDrive/Project/Dataset/source_files/source_files"
demo_base = "/content/drive/MyDrive/Project/Dataset/yolov8_ppe_detection/visual_demo"

img_demo = os.path.join(demo_base, "images")
vid_demo = os.path.join(demo_base, "videos")

# Ensure folders exist
os.makedirs(img_demo, exist_ok=True)
os.makedirs(vid_demo, exist_ok=True)

# Copy all image files
image_files = glob.glob(f"{src_folder}/*.jpg") + glob.glob(f"{src_folder}/*.png")
for img in image_files:
    shutil.copy(img, img_demo)
    print(f"📸 Copied image: {os.path.basename(img)}")

# Copy all video files
video_files = glob.glob(f"{src_folder}/*.mp4")
for vid in video_files:
    shutil.copy(vid, vid_demo)
    print(f"Copied video: {os.path.basename(vid)}")

print("\nAll images and videos copied successfully!")
print("Images folder:", img_demo)
print("Videos folder:", vid_demo)
# Out:
# 📸 Copied image: construction-safety.jpg
# 📸 Copied image: two-young-construction-workers-wearing-555864.jpg
# 📸 Copied image: schupan_japan1web.jpg
# 📸 Copied image: portrait-of-woman-with-mask-and-man-with-safety-glasses-on-a-construction-HX01FH.jpg
# 🎞️ Copied video: hardhat.mp4
# 🎞️ Copied video: JapanPPE.mp4
# 🎞️ Copied video: indianworkers.mp4
#
# ✅ All images and videos copied successfully!
# 📂 Images folder: /content/drive/MyDrive/Project/Dataset/yolov8_ppe_detection/visual_demo/images
# 📂 Videos folder: /content/drive/MyDrive/Project/Dataset/yolov8_ppe_detection/visual_demo/videos

# %%
import cv2
import torch
import os
from ultralytics import YOLO
from datetime import datetime

# ==============================
# 🔧 CONFIGURATION
# ==============================
MODEL_PATH = "/content/drive/MyDrive/Project/Dataset/css-data/cross_validation/results_fold3/weights/best.pt"
VIDEO_PATH = "/content/drive/MyDrive/Project/Dataset/yolov8_ppe_detection/visual_demo/videos/JapanPPE.mp4"
OUTPUT_DIR = "/content/drive/MyDrive/Project/Dataset/runs/yolov8_ppe_detection/visual_demo/outputs/RuleTesting"
os.makedirs(OUTPUT_DIR, exist_ok=True)

CONF_THRES = 0.5
IOU_THRES = 0.45
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"🖥️ Using device: {DEVICE}")

# ==============================
# 🎯 LOAD MODEL
# ==============================
model = YOLO(MODEL_PATH)
model.to(DEVICE)
print("✅ Model loaded successfully!")

# ==============================
# ⚙️ RULE EVALUATION FUNCTION
# ==============================
def evaluate_rules_all_classes(detections):
    """
    Evaluate PPE compliance for all YOLO classes.
    Marks non-compliance when 'NO-' labels are detected or PPE is missing.
    """
    gear_present = {'Hardhat': False, 'Mask': False, 'Safety Vest': False}
    violations = []

    for det in detections:
        label = det['label']

        # --- Violations ---
        if label in ['NO-Hardhat', 'NO-Mask', 'NO-Safety Vest']:
            violations.append(label.replace('NO-', 'No '))

        # --- PPE present ---
        elif label in ['Hardhat', 'Mask', 'Safety Vest']:
            gear_present[label] = True

    # --- Check for missing PPE if not explicitly detected ---
    if not gear_present['Hardhat'] and all(v != 'No Hardhat' for v in violations):
        violations.append('No Hardhat (Missing)')
    if not gear_present['Safety Vest'] and all(v != 'No Safety Vest' for v in violations):
        violations.append('No Safety Vest (Missing)')
    if not gear_present['Mask'] and all(v != 'No Mask' for v in violations):
        violations.append('No Mask (Missing)')

    if len(violations) == 0:
        return {"status": "Compliant", "violations": [], "color": (0, 255, 0)}
    else:
        return {"status": "Violation", "violations": violations, "color": (0, 0, 255)}

# ==============================
# 🎥 VIDEO INFERENCE LOOP
# ==============================
cap = cv2.VideoCapture(VIDEO_PATH)
if not cap.isOpened():
    raise FileNotFoundError(f"❌ Could not open video: {VIDEO_PATH}")

fps = cap.get(cv2.CAP_PROP_FPS)
w, h = int(cap.get(3)), int(cap.get(4))

output_path = os.path.join(OUTPUT_DIR, "ppe_violation_output.mp4")
out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (w, h))

frame_id = 0
log_path = os.path.join(OUTPUT_DIR, "violation_log.txt")

print("🚀 Running inference... Press Ctrl+C to stop early.")

with open(log_path, "w") as log_file:
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frame_id += 1

        results = model.predict(frame, conf=CONF_THRES, iou=IOU_THRES, imgsz=640, device=DEVICE, verbose=False)

        detections = []
        for box in results[0].boxes:
            label = model.names[int(box.cls[0])]
            conf = float(box.conf[0])
            detections.append({'label': label, 'conf': conf})

        rule_result = evaluate_rules_all_classes(detections)

        # Draw boxes
        for box in results[0].boxes:
            cls = int(box.cls[0])
            label = model.names[cls]
            conf = float(box.conf[0])
            x1, y1, x2, y2 = map(int, box.xyxy[0])

            if label.startswith("NO-"):
                color = (0, 0, 255)  # Red for violations
            elif label in ["Hardhat", "Mask", "Safety Vest"]:
                color = (0, 255, 0)  # Green for compliant PPE
            else:
                color = (255, 255, 0)  # Yellow for neutral (Person, Cone, etc.)

            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, f"{label} {conf:.2f}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

        # Overlay compliance status
        cv2.putText(frame, f"Status: {rule_result['status']}",
                    (30, 40), cv2.FONT_HERSHEY_SIMPLEX, 1,
                    rule_result['color'], 3)

        # Log violations
        if rule_result["status"] == "Violation":
            ts = datetime.now().strftime("%H:%M:%S")
            log_entry = f"[{ts}] Frame {frame_id}: {rule_result['violations']}\n"
            log_file.write(log_entry)
            print(log_entry.strip())

        out.write(frame)

cap.release()
out.release()
print(f"\n✅ Inference completed. Saved output video at:\n{output_path}")
print(f"🧾 Violation log saved at:\n{log_path}")
# Out:
# 🖥️ Using device: cpu
# ✅ Model loaded successfully!
# 🚀 Running inference... Press Ctrl+C to stop early.
# [16:36:56] Frame 1: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:36:57] Frame 2: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:36:57] Frame 3: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:36:58] Frame 4: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:36:58] Frame 5: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:36:59] Frame 6: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:36:59] Frame 7: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:36:59] Frame 8: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:00] Frame 9: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:00] Frame 10: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:00] Frame 11: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:01] Frame 12: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:01] Frame 13: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:01] Frame 14: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:02] Frame 15: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:02] Frame 16: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:03] Frame 17: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:03] Frame 18: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:03] Frame 19: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:04] Frame 20: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:04] Frame 21: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:04] Frame 22: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:05] Frame 23: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:05] Frame 24: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:05] Frame 25: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:06] Frame 26: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:06] Frame 27: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:06] Frame 28: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:07] Frame 29: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:07] Frame 30: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:08] Frame 31: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:08] Frame 32: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:08] Frame 33: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:09] Frame 34: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:09] Frame 35: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:10] Frame 36: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:11] Frame 37: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:11] Frame 38: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:12] Frame 39: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:12] Frame 40: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:12] Frame 41: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:13] Frame 42: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:13] Frame 43: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:13] Frame 44: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:14] Frame 45: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:14] Frame 46: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:14] Frame 47: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:15] Frame 48: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:15] Frame 49: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:16] Frame 50: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:16] Frame 51: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:16] Frame 52: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:17] Frame 53: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:17] Frame 54: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:17] Frame 55: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:18] Frame 56: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:18] Frame 57: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:18] Frame 58: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:19] Frame 59: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:19] Frame 60: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:19] Frame 61: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:20] Frame 62: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:20] Frame 63: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:21] Frame 64: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:21] Frame 65: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:21] Frame 66: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:22] Frame 67: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:22] Frame 68: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:23] Frame 69: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:23] Frame 70: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:24] Frame 71: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:24] Frame 72: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:25] Frame 73: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:25] Frame 74: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:26] Frame 75: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:26] Frame 76: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:27] Frame 77: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:27] Frame 78: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:27] Frame 79: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:28] Frame 80: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:28] Frame 81: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:28] Frame 82: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:29] Frame 83: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:29] Frame 84: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:29] Frame 85: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:30] Frame 86: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:30] Frame 87: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:30] Frame 88: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:31] Frame 89: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:31] Frame 90: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:32] Frame 91: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:32] Frame 92: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:32] Frame 93: ['No Safety Vest', 'No Hardhat (Missing)', 'No Mask (Missing)']
# [16:37:33] Frame 94: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:33] Frame 95: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:33] Frame 96: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:34] Frame 97: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:34] Frame 98: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:34] Frame 99: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:35] Frame 100: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:35] Frame 101: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:35] Frame 102: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:36] Frame 103: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:36] Frame 104: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:37] Frame 105: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:38] Frame 106: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:38] Frame 107: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:39] Frame 108: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:39] Frame 109: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:40] Frame 110: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:40] Frame 111: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:40] Frame 112: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:41] Frame 113: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:41] Frame 114: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:41] Frame 115: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:42] Frame 116: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:42] Frame 117: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:43] Frame 118: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:43] Frame 119: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:43] Frame 120: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:44] Frame 121: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:44] Frame 122: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:44] Frame 123: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:45] Frame 124: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:45] Frame 125: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:45] Frame 126: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:46] Frame 127: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:46] Frame 128: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:46] Frame 129: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:47] Frame 130: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:47] Frame 131: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:47] Frame 132: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:48] Frame 133: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:48] Frame 134: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:49] Frame 135: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:49] Frame 136: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:49] Frame 137: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:50] Frame 138: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:50] Frame 139: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:51] Frame 140: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:51] Frame 141: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:52] Frame 142: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:52] Frame 143: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:53] Frame 144: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:53] Frame 145: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:54] Frame 146: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:54] Frame 147: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:54] Frame 148: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:55] Frame 149: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:55] Frame 150: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:56] Frame 151: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:56] Frame 152: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:56] Frame 153: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:57] Frame 154: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:57] Frame 155: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:58] Frame 156: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:58] Frame 157: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:58] Frame 158: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:59] Frame 159: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:59] Frame 160: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:37:59] Frame 161: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:00] Frame 162: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:00] Frame 163: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:01] Frame 164: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:01] Frame 165: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:01] Frame 166: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:02] Frame 167: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:02] Frame 168: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:02] Frame 169: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:03] Frame 170: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:03] Frame 171: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:04] Frame 172: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:04] Frame 173: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:05] Frame 174: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:05] Frame 175: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:06] Frame 176: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:06] Frame 177: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:07] Frame 178: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:08] Frame 179: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:08] Frame 180: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:09] Frame 181: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:09] Frame 182: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:09] Frame 183: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:10] Frame 184: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:10] Frame 185: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:11] Frame 186: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:11] Frame 187: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:11] Frame 188: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:12] Frame 189: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:12] Frame 190: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:12] Frame 191: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:13] Frame 192: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:13] Frame 193: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:13] Frame 194: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:14] Frame 195: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:14] Frame 196: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:14] Frame 197: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:15] Frame 198: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:15] Frame 199: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:15] Frame 200: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:16] Frame 201: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:16] Frame 202: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:17] Frame 203: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:17] Frame 204: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:17] Frame 205: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:18] Frame 206: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:18] Frame 207: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:19] Frame 208: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:19] Frame 209: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:20] Frame 210: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:20] Frame 211: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:21] Frame 212: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:21] Frame 213: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:22] Frame 214: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:22] Frame 215: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:22] Frame 216: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:23] Frame 217: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:23] Frame 218: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:23] Frame 219: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:24] Frame 220: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:24] Frame 221: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:25] Frame 222: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:25] Frame 223: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:25] Frame 224: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:26] Frame 225: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:26] Frame 226: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:26] Frame 227: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:27] Frame 228: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:27] Frame 229: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:27] Frame 230: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:28] Frame 231: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:28] Frame 232: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:28] Frame 233: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:29] Frame 234: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:29] Frame 235: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:29] Frame 236: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:30] Frame 237: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:30] Frame 238: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:30] Frame 239: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:31] Frame 240: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:31] Frame 241: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:32] Frame 242: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:32] Frame 243: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:33] Frame 244: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:33] Frame 245: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:34] Frame 246: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:34] Frame 247: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:35] Frame 248: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:35] Frame 249: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:36] Frame 250: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:36] Frame 251: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:36] Frame 252: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:37] Frame 253: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:37] Frame 254: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:37] Frame 255: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:38] Frame 256: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:38] Frame 257: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:38] Frame 258: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:39] Frame 259: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:39] Frame 260: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:40] Frame 261: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:40] Frame 262: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:40] Frame 263: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:41] Frame 264: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:41] Frame 265: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:41] Frame 266: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:42] Frame 267: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:42] Frame 268: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:42] Frame 269: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:43] Frame 270: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:43] Frame 271: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:44] Frame 272: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:44] Frame 273: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:44] Frame 274: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:45] Frame 275: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:45] Frame 276: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:46] Frame 277: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:46] Frame 278: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:47] Frame 279: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:47] Frame 280: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:48] Frame 281: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:48] Frame 282: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:49] Frame 283: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:49] Frame 284: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:49] Frame 285: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:50] Frame 286: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:50] Frame 287: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:51] Frame 288: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:51] Frame 289: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:51] Frame 290: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:52] Frame 291: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:52] Frame 292: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:52] Frame 293: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:53] Frame 294: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:53] Frame 295: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:53] Frame 296: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:54] Frame 297: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:54] Frame 298: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:54] Frame 299: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:55] Frame 300: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:55] Frame 301: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:56] Frame 302: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:56] Frame 303: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:56] Frame 304: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:57] Frame 305: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:57] Frame 306: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:57] Frame 307: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:58] Frame 308: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:58] Frame 309: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:58] Frame 310: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:59] Frame 311: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:38:59] Frame 312: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:00] Frame 313: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:01] Frame 314: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:01] Frame 315: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:02] Frame 316: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:02] Frame 317: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:03] Frame 318: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:03] Frame 319: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:03] Frame 320: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:04] Frame 321: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:04] Frame 322: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:04] Frame 323: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:05] Frame 324: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:05] Frame 325: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:06] Frame 326: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:06] Frame 327: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:06] Frame 328: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:07] Frame 329: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:07] Frame 330: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:07] Frame 331: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:08] Frame 332: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:08] Frame 333: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:08] Frame 334: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:09] Frame 335: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:09] Frame 336: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:10] Frame 337: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:10] Frame 338: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:10] Frame 339: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:11] Frame 340: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:11] Frame 341: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:11] Frame 342: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:12] Frame 343: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:12] Frame 344: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:12] Frame 345: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:13] Frame 346: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:13] Frame 347: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:14] Frame 348: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:15] Frame 349: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:15] Frame 350: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:16] Frame 351: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:16] Frame 352: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:17] Frame 353: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:17] Frame 354: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:17] Frame 355: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:18] Frame 356: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:18] Frame 357: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:18] Frame 358: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:19] Frame 359: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:19] Frame 360: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:19] Frame 361: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:20] Frame 362: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:20] Frame 363: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:21] Frame 364: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:21] Frame 365: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:21] Frame 366: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:22] Frame 367: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:22] Frame 368: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:22] Frame 369: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:23] Frame 370: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:23] Frame 371: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:23] Frame 372: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:24] Frame 373: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:24] Frame 374: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:24] Frame 375: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:25] Frame 376: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:25] Frame 377: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:26] Frame 378: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:26] Frame 379: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:26] Frame 380: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:27] Frame 381: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:27] Frame 382: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:28] Frame 383: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:29] Frame 384: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:29] Frame 385: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:30] Frame 386: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:30] Frame 387: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:30] Frame 388: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:31] Frame 389: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:31] Frame 390: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:31] Frame 391: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:32] Frame 392: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:32] Frame 393: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:33] Frame 394: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:33] Frame 395: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:33] Frame 396: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:34] Frame 397: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:34] Frame 398: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:34] Frame 399: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:35] Frame 400: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:35] Frame 401: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:35] Frame 402: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:36] Frame 403: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:36] Frame 404: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:37] Frame 405: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:37] Frame 406: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:37] Frame 407: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:38] Frame 408: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:38] Frame 409: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:38] Frame 410: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:39] Frame 411: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:39] Frame 412: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:39] Frame 413: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:40] Frame 414: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:40] Frame 415: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:41] Frame 416: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:41] Frame 417: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:42] Frame 418: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:43] Frame 419: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:43] Frame 420: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:44] Frame 421: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:44] Frame 422: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:44] Frame 423: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:45] Frame 424: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:45] Frame 425: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:45] Frame 426: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:46] Frame 427: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:46] Frame 428: ['No Safety Vest', 'No Hardhat (Missing)', 'No Mask (Missing)']
# [16:39:47] Frame 429: ['No Safety Vest', 'No Hardhat (Missing)', 'No Mask (Missing)']
# [16:39:47] Frame 430: ['No Safety Vest', 'No Hardhat (Missing)', 'No Mask (Missing)']
# [16:39:47] Frame 431: ['No Safety Vest', 'No Hardhat (Missing)', 'No Mask (Missing)']
# [16:39:48] Frame 432: ['No Safety Vest', 'No Mask (Missing)']
# [16:39:48] Frame 433: ['No Safety Vest', 'No Mask (Missing)']
# [16:39:48] Frame 434: ['No Safety Vest', 'No Hardhat (Missing)', 'No Mask (Missing)']
# [16:39:49] Frame 435: ['No Safety Vest', 'No Hardhat (Missing)', 'No Mask (Missing)']
# [16:39:49] Frame 436: ['No Safety Vest', 'No Hardhat (Missing)', 'No Mask (Missing)']
# [16:39:49] Frame 437: ['No Safety Vest', 'No Hardhat (Missing)', 'No Mask (Missing)']
# [16:39:50] Frame 438: ['No Safety Vest', 'No Hardhat (Missing)', 'No Mask (Missing)']
# [16:39:50] Frame 439: ['No Safety Vest', 'No Hardhat (Missing)', 'No Mask (Missing)']
# [16:39:51] Frame 440: ['No Safety Vest', 'No Hardhat (Missing)', 'No Mask (Missing)']
# [16:39:51] Frame 441: ['No Safety Vest', 'No Hardhat (Missing)', 'No Mask (Missing)']
# [16:39:51] Frame 442: ['No Safety Vest', 'No Hardhat (Missing)', 'No Mask (Missing)']
# [16:39:52] Frame 443: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:52] Frame 444: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:53] Frame 445: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:53] Frame 446: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:54] Frame 447: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:55] Frame 448: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:56] Frame 449: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:58] Frame 450: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:59] Frame 451: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:59] Frame 452: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:39:59] Frame 453: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:00] Frame 454: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:00] Frame 455: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:00] Frame 456: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:01] Frame 457: ['No Safety Vest', 'No Hardhat (Missing)', 'No Mask (Missing)']
# [16:40:01] Frame 458: ['No Safety Vest', 'No Hardhat (Missing)', 'No Mask (Missing)']
# [16:40:02] Frame 459: ['No Safety Vest', 'No Hardhat (Missing)', 'No Mask (Missing)']
# [16:40:02] Frame 460: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:02] Frame 461: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:03] Frame 462: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:03] Frame 463: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:04] Frame 464: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:04] Frame 465: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:04] Frame 466: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:05] Frame 467: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:05] Frame 468: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:05] Frame 469: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:06] Frame 470: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:06] Frame 471: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:07] Frame 472: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:07] Frame 473: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:07] Frame 474: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:08] Frame 475: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:08] Frame 476: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:09] Frame 477: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:09] Frame 478: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:10] Frame 479: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:10] Frame 480: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:11] Frame 481: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:11] Frame 482: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:12] Frame 483: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:12] Frame 484: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:13] Frame 485: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:13] Frame 486: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:14] Frame 487: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:14] Frame 488: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:14] Frame 489: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:15] Frame 490: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:15] Frame 491: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:15] Frame 492: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:16] Frame 493: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:16] Frame 494: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:17] Frame 495: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:17] Frame 496: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:17] Frame 497: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:18] Frame 498: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:18] Frame 499: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:18] Frame 500: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:19] Frame 501: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [16:40:19] Frame 502: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# ...
# [17:08:46] Frame 4621: ['No Safety Vest', 'No Hardhat (Missing)', 'No Mask (Missing)']
# [17:08:46] Frame 4622: ['No Safety Vest', 'No Hardhat (Missing)', 'No Mask (Missing)']
# [17:08:47] Frame 4623: ['No Safety Vest', 'No Hardhat (Missing)', 'No Mask (Missing)']
# [17:08:47] Frame 4624: ['No Safety Vest', 'No Hardhat (Missing)', 'No Mask (Missing)']
# [17:08:47] Frame 4625: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:08:48] Frame 4626: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:08:48] Frame 4627: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:08:49] Frame 4628: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:08:49] Frame 4629: ['No Hardhat (Missing)', 'No Mask (Missing)']
# [17:08:49] Frame 4630: ['No Hardhat (Missing)', 'No Mask (Missing)']
# [17:08:50] Frame 4631: ['No Hardhat (Missing)', 'No Mask (Missing)']
# [17:08:50] Frame 4632: ['No Hardhat (Missing)', 'No Mask (Missing)']
# [17:08:50] Frame 4633: ['No Hardhat (Missing)', 'No Mask (Missing)']
# [17:08:51] Frame 4634: ['No Hardhat (Missing)', 'No Mask (Missing)']
# [17:08:51] Frame 4635: ['No Hardhat (Missing)', 'No Mask (Missing)']
# [17:08:51] Frame 4636: ['No Hardhat (Missing)', 'No Mask (Missing)']
# [17:08:52] Frame 4637: ['No Hardhat (Missing)', 'No Mask (Missing)']
# [17:08:52] Frame 4638: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:08:53] Frame 4639: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:08:53] Frame 4640: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:08:53] Frame 4641: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:08:54] Frame 4642: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:08:54] Frame 4643: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:08:54] Frame 4644: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:08:55] Frame 4645: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:08:55] Frame 4646: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:08:56] Frame 4647: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:08:56] Frame 4648: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:08:57] Frame 4649: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:08:57] Frame 4650: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:08:58] Frame 4651: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:08:59] Frame 4652: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:08:59] Frame 4653: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:08:59] Frame 4654: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:00] Frame 4655: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:00] Frame 4656: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:00] Frame 4657: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:01] Frame 4658: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:01] Frame 4659: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:01] Frame 4660: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:02] Frame 4661: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:02] Frame 4662: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:03] Frame 4663: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:03] Frame 4664: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:03] Frame 4665: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:04] Frame 4666: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:04] Frame 4667: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:04] Frame 4668: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:05] Frame 4669: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:05] Frame 4670: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:05] Frame 4671: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:06] Frame 4672: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:06] Frame 4673: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:06] Frame 4674: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:07] Frame 4675: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:07] Frame 4676: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:08] Frame 4677: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:08] Frame 4678: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:08] Frame 4679: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:09] Frame 4680: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:09] Frame 4681: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:10] Frame 4682: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:10] Frame 4683: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:11] Frame 4684: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:11] Frame 4685: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:12] Frame 4686: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:12] Frame 4687: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:13] Frame 4688: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:13] Frame 4689: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:14] Frame 4690: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:14] Frame 4691: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:14] Frame 4692: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:15] Frame 4693: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:15] Frame 4694: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:15] Frame 4695: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:16] Frame 4696: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:16] Frame 4697: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:16] Frame 4698: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:17] Frame 4699: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:17] Frame 4700: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:17] Frame 4701: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:18] Frame 4702: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:18] Frame 4703: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:18] Frame 4704: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:19] Frame 4705: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:19] Frame 4706: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:20] Frame 4707: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:20] Frame 4708: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:20] Frame 4709: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:21] Frame 4710: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:21] Frame 4711: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:21] Frame 4712: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:22] Frame 4713: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:22] Frame 4714: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:22] Frame 4715: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:23] Frame 4716: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:23] Frame 4717: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:24] Frame 4718: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:25] Frame 4719: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:25] Frame 4720: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:26] Frame 4721: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:26] Frame 4722: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:27] Frame 4723: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:27] Frame 4724: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:27] Frame 4725: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:28] Frame 4726: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:28] Frame 4727: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:28] Frame 4728: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:29] Frame 4729: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:29] Frame 4730: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:29] Frame 4731: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:30] Frame 4732: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:30] Frame 4733: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:30] Frame 4734: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:31] Frame 4735: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:31] Frame 4736: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:32] Frame 4737: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:32] Frame 4738: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:32] Frame 4739: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:33] Frame 4740: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:33] Frame 4741: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:33] Frame 4742: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:34] Frame 4743: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:34] Frame 4744: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:34] Frame 4745: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:35] Frame 4746: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:35] Frame 4747: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:35] Frame 4748: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:36] Frame 4749: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:36] Frame 4750: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:37] Frame 4751: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:37] Frame 4752: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:38] Frame 4753: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:38] Frame 4754: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:39] Frame 4755: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:40] Frame 4756: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:40] Frame 4757: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:41] Frame 4758: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:41] Frame 4759: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:42] Frame 4760: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:43] Frame 4761: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:43] Frame 4762: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:44] Frame 4763: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:44] Frame 4764: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:44] Frame 4765: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:45] Frame 4766: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:45] Frame 4767: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:45] Frame 4768: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:46] Frame 4769: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:46] Frame 4770: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:47] Frame 4771: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:47] Frame 4772: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:47] Frame 4773: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:48] Frame 4774: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:48] Frame 4775: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:48] Frame 4776: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:49] Frame 4777: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:49] Frame 4778: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:49] Frame 4779: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:50] Frame 4780: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:50] Frame 4781: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:51] Frame 4782: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:51] Frame 4783: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
# [17:09:51] Frame 4784: ['No Hardhat (Missing)', 'No Safety Vest (Missing)', 'No Mask (Missing)']
#
# ✅ Inference completed. Saved output video at:
# /content/drive/MyDrive/Project/Dataset/runs/yolov8_ppe_detection/visual_demo/outputs/RuleTesting/ppe_violation_output.mp4
# 🧾 Violation log saved at:
# /content/drive/MyDrive/Project/Dataset/runs/yolov8_ppe_detection/visual_demo/outputs/RuleTesting/violation_log.txt

# %%
import cv2
import torch
import time
from ultralytics import YOLO
import os
from google.colab.patches import cv2_imshow
from IPython.display import Video

# === Configuration ===
MODEL_PATH = "/content/drive/MyDrive/Project/Dataset/css-data/cross_validation/results_fold3/weights/best.pt"
VIDEO_PATH = "/content/drive/MyDrive/Project/Dataset/source_files/source_files/hardhat.mp4"

# 👇 Folder fix: create ALL parent directories properly
OUTPUT_DIR = "/content/drive/MyDrive/Project/Dataset/runs/yolov8_ppe_detection/visual_demo/outputs/RuleTesting"
os.makedirs(OUTPUT_DIR, exist_ok=True)

OUTPUT_VIDEO = os.path.join(OUTPUT_DIR, "ppe_violation_output.mp4")
LOG_FILE = os.path.join(OUTPUT_DIR, "violation_log.txt")

CONF_THRES = 0.5
IOU_THRES = 0.45
IMG_SIZE = 640
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# === Load Model ===
model = YOLO(MODEL_PATH)
print(f"✅ Model loaded on {DEVICE.upper()}")

# === Define class colors ===
RED_CLASSES = ["NO-Hardhat", "NO-Mask", "NO-Safety Vest"]
GREEN_CLASSES = ["Hardhat", "Mask", "Safety Vest"]
YELLOW_CLASSES = ["Person", "Machinery", "Vehicle", "Safety Cone"]

# === Video setup ===
cap = cv2.VideoCapture(VIDEO_PATH)
if not cap.isOpened():
    raise FileNotFoundError(f"❌ Could not open video file: {VIDEO_PATH}")

fps = int(cap.get(cv2.CAP_PROP_FPS)) or 30
width, height = int(cap.get(3)), int(cap.get(4))
out = cv2.VideoWriter(OUTPUT_VIDEO, cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

# 👇 Make sure log file is open correctly
log = open(LOG_FILE, "w", buffering=1)  # line-buffered (auto flush)

prev_time = time.time()
frame_id = 0

print("🚀 Processing video... please wait")

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    frame_id += 1

    # Run detection
    results = model.predict(frame, conf=CONF_THRES, iou=IOU_THRES, imgsz=IMG_SIZE, device=DEVICE, verbose=False)
    detections = results[0].boxes.data.cpu().numpy() if len(results) > 0 else []

    violations = []
    people_count = 0

    # Draw detections
    for box in results[0].boxes:
        cls_id = int(box.cls)
        label = model.names[cls_id]
        conf = float(box.conf)
        x1, y1, x2, y2 = map(int, box.xyxy[0])

        # Color by class
        color = (255, 255, 0)
        if label in GREEN_CLASSES:
            color = (0, 255, 0)
        elif label in RED_CLASSES:
            color = (0, 0, 255)

        cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
        cv2.putText(frame, f"{label} {conf:.2f}", (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

        if label == "Person":
            people_count += 1
        if label in RED_CLASSES:
            violations.append(label)

    curr_time = time.time()
    fps_calc = 1 / (curr_time - prev_time)
    prev_time = curr_time

    status_text = "Compliant" if len(violations) == 0 else "Violation Detected"
    status_color = (0, 255, 0) if len(violations) == 0 else (0, 0, 255)

    cv2.rectangle(frame, (10, 10), (360, 100), (40, 40, 40), -1)
    cv2.putText(frame, f"FPS: {fps_calc:.1f}", (20, 35), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 2)
    cv2.putText(frame, f"People: {people_count}", (20, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 2)
    cv2.putText(frame, f"Violations: {len(violations)}", (180, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0,0,255), 2)
    cv2.putText(frame, f"Status: {status_text}", (20, 90), cv2.FONT_HERSHEY_SIMPLEX, 0.6, status_color, 2)

    # ✅ Log violations if any
    if violations:
        log.write(f"[Frame {frame_id}] Violations: {violations}\n")

    out.write(frame)

    # ✅ Show first few frames inline for preview
    if frame_id <= 10:
        cv2_imshow(frame)

cap.release()
out.release()
log.close()

print(f"\n✅ Processed video saved at: {OUTPUT_VIDEO}")
print(f"🧾 Violation log saved at: {LOG_FILE}")

# Optional: show playable video
Video(OUTPUT_VIDEO, embed=True)

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install ultralytics opencv-python torch torchvision torchaudio pandas matplotlib
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Collecting ultralytics
#   Downloading ultralytics-8.3.223-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.25.2)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Downloading ultralytics-8.3.223-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.5 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.223 ultralytics-thop-2.0.18

# %%
MODEL_PATH = "/content/drive/MyDrive/Project/Dataset/css-data/cross_validation/results_fold3/weights/best.pt"

# %%
import cv2, torch, time, os, glob
from ultralytics import YOLO
from google.colab.patches import cv2_imshow
from IPython.display import Video

# Paths
MODEL_PATH = "/content/drive/MyDrive/Project/Dataset/css-data/cross_validation/results_fold3/weights/best.pt"
VIDEO_DIR = "/content/drive/MyDrive/Project/Dataset/yolov8_ppe_detection/testVideos"  # folder with your test videos
OUTPUT_DIR = "/content/drive/MyDrive/Project/Dataset/runs/yolov8_ppe_detection/visual_demo/outputs/RuleTesting"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Config
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
CONF_THRES, IOU_THRES, IMG_SIZE = 0.5, 0.45, 640
print(f"✅ Using device: {DEVICE}")

# Load model
model = YOLO(MODEL_PATH)

# Class colors
RED_CLASSES = ["NO-Hardhat", "NO-Mask", "NO-Safety Vest"]
GREEN_CLASSES = ["Hardhat", "Mask", "Safety Vest"]
YELLOW_CLASSES = ["Person", "Machinery", "Vehicle", "Safety Cone"]

# Collect all mp4 files in the folder
video_files = sorted(glob.glob(os.path.join(VIDEO_DIR, "*.mp4")))

if not video_files:
    print("⚠️ No video files found in", VIDEO_DIR)
else:
    print(f"🎥 Found {len(video_files)} videos to process.")

# Process each video
for VIDEO_PATH in video_files:
    base_name = os.path.basename(VIDEO_PATH)
    OUTPUT_VIDEO = os.path.join(OUTPUT_DIR, f"{os.path.splitext(base_name)[0]}_rule_output.mp4")
    LOG_FILE = os.path.join(OUTPUT_DIR, f"{os.path.splitext(base_name)[0]}_violations.txt")

    print(f"\n▶️ Processing {base_name}...")

    cap = cv2.VideoCapture(VIDEO_PATH)
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width, height = int(cap.get(3)), int(cap.get(4))
    out = cv2.VideoWriter(OUTPUT_VIDEO, cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))
    log = open(LOG_FILE, "w")

    prev_time = time.time()
    frame_id = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        frame_id += 1

        results = model.predict(frame, conf=CONF_THRES, iou=IOU_THRES, imgsz=IMG_SIZE, device=DEVICE, verbose=False)
        violations, people_count = [], 0

        for box in results[0].boxes:
            cls_id = int(box.cls)
            label = model.names[cls_id]
            conf = float(box.conf)
            x1, y1, x2, y2 = map(int, box.xyxy[0])

            color = (255, 255, 0)
            if label in GREEN_CLASSES: color = (0, 255, 0)
            elif label in RED_CLASSES: color = (0, 0, 255)

            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, f"{label} {conf:.2f}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

            if label == "Person": people_count += 1
            if label in RED_CLASSES: violations.append(label)

        fps_calc = 1 / (time.time() - prev_time)
        prev_time = time.time()

        status = "Compliant" if not violations else "Violation Detected"
        status_color = (0, 255, 0) if not violations else (0, 0, 255)

        cv2.rectangle(frame, (10, 10), (360, 100), (40, 40, 40), -1)
        cv2.putText(frame, f"FPS: {fps_calc:.1f}", (20, 35), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 2)
        cv2.putText(frame, f"People: {people_count}", (20, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255,255,255), 2)
        cv2.putText(frame, f"Violations: {len(violations)}", (180, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0,0,255), 2)
        cv2.putText(frame, f"Status: {status}", (20, 90), cv2.FONT_HERSHEY_SIMPLEX, 0.6, status_color, 2)

        if violations:
            log.write(f"[Frame {frame_id}] Violations: {violations}\n")

        out.write(frame)
        if frame_id == 1:
            cv2_imshow(frame)  # just preview first frame

    cap.release()
    out.release()
    log.close()

    print(f"✅ Completed: {base_name}")
    print(f"🎬 Output saved: {OUTPUT_VIDEO}")
    print(f"🧾 Log saved: {LOG_FILE}")

print("\n🏁 All videos processed successfully!")

# %%
import os
import pandas as pd
import re

# === Paths ===
LOG_DIR = "/content/drive/MyDrive/Project/Dataset/runs/yolov8_ppe_detection/visual_demo/outputs/RuleTesting"
OUTPUT_CSV = os.path.join(LOG_DIR, "rule_test_log.csv")

entries = []

# Scan all .txt logs
for file in os.listdir(LOG_DIR):
    if file.endswith(".txt"):
        video_name = file.replace(".txt", "")
        with open(os.path.join(LOG_DIR, file), "r") as f:
            for line in f:
                match = re.search(r"\[Frame (\d+)\] Violations: (.*)", line)
                if match:
                    frame = int(match.group(1))
                    violations = match.group(2).strip()
                    entries.append({
                        "Video": video_name,
                        "Frame": frame,
                        "Violations": violations
                    })

# Save as CSV
df = pd.DataFrame(entries)
df.to_csv(OUTPUT_CSV, index=False)
print(f"✅ Combined log saved to: {OUTPUT_CSV}")
# Out:
# ✅ Combined log saved to: /content/drive/MyDrive/Project/Dataset/runs/yolov8_ppe_detection/visual_demo/outputs/RuleTesting/rule_test_log.csv

# %%
import os
import pandas as pd

# === Paths ===
LOG_DIR = "/content/drive/MyDrive/Project/Dataset/runs/yolov8_ppe_detection/visual_demo/outputs/RuleTesting"
LOG_CSV = os.path.join(LOG_DIR, "rule_test_log.csv")
SUMMARY_TXT = os.path.join(LOG_DIR, "violations_summary.txt")
SUMMARY_CSV = os.path.join(LOG_DIR, "performance_summary.csv")

# Load combined log
df = pd.read_csv(LOG_CSV)

summary = []
for video, group in df.groupby("Video"):
    total_frames = group["Frame"].max()
    violations = len(group)
    compliance_rate = round(100 * (1 - violations / total_frames), 2)
    summary.append({
        "Video": video,
        "Total Frames": total_frames,
        "Violations": violations,
        "Compliance Rate (%)": compliance_rate,
        "Pass/Fail": "✅ Pass" if compliance_rate >= 95 else "❌ Fail"
    })

summary_df = pd.DataFrame(summary)
summary_df.to_csv(SUMMARY_CSV, index=False)

# Write human-readable summary
with open(SUMMARY_TXT, "w") as f:
    f.write("=== PPE Violation Summary ===\n\n")
    for _, row in summary_df.iterrows():
        f.write(f"🎬 {row['Video']}\n")
        f.write(f"   Frames: {row['Total Frames']}\n")
        f.write(f"   Violations: {row['Violations']}\n")
        f.write(f"   Compliance: {row['Compliance Rate (%)']}%\n")
        f.write(f"   Result: {row['Pass/Fail']}\n\n")

print(f"📊 Summary CSV saved: {SUMMARY_CSV}")
print(f"🧾 Text summary saved: {SUMMARY_TXT}")
# Out:
# 📊 Summary CSV saved: /content/drive/MyDrive/Project/Dataset/runs/yolov8_ppe_detection/visual_demo/outputs/RuleTesting/performance_summary.csv
# 🧾 Text summary saved: /content/drive/MyDrive/Project/Dataset/runs/yolov8_ppe_detection/visual_demo/outputs/RuleTesting/violations_summary.txt

# %%
import pandas as pd
from fpdf import FPDF
import os

LOG_DIR = "/content/drive/MyDrive/Project/Dataset/runs/yolov8_ppe_detection/visual_demo/outputs/RuleTesting"
SUMMARY_CSV = os.path.join(LOG_DIR, "performance_summary.csv")
REPORT_MD = os.path.join(LOG_DIR, "integration_test_report.md")
REPORT_PDF = os.path.join(LOG_DIR, "integration_test_report.pdf")

df = pd.read_csv(SUMMARY_CSV)

# === Generate Markdown Report ===
with open(REPORT_MD, "w") as f:
    f.write("# 🧩 Integration Test Report\n\n")
    f.write("## Model Evaluation Summary\n\n")
    f.write(df.to_markdown(index=False))
    f.write("\n\n## Notes\n")
    f.write("- Red boxes indicate missing PPE.\n")
    f.write("- Green boxes indicate compliance.\n")
    f.write("- Yellow boxes are neutral objects.\n")
    f.write("- Thresholds: conf=0.5, iou=0.45\n")

print(f"✅ Markdown report saved at: {REPORT_MD}")

# === Convert to PDF ===
pdf = FPDF()
pdf.add_page()
pdf.set_font("Arial", "B", 16)
pdf.cell(0, 10, "Integration Test Report", ln=True)
pdf.ln(10) # Add some space

pdf.set_font("Arial", size=12)

# Add table headers
col_widths = [50, 25, 25, 35, 30]
headers = ["Video", "Total Frames", "Violations", "Compliance Rate (%)", "Pass/Fail"]
for i, header in enumerate(headers):
    pdf.cell(col_widths[i], 10, header, 1, 0, 'C')
pdf.ln()

# Add table rows
for i, row in df.iterrows():
    # Remove problematic characters before writing to PDF
    pass_fail_text = str(row['Pass/Fail']).replace('✅', 'Pass').replace('❌', 'Fail')
    pdf.cell(col_widths[0], 10, str(row['Video']), 1, 0, 'L')
    pdf.cell(col_widths[1], 10, str(row['Total Frames']), 1, 0, 'C')
    pdf.cell(col_widths[2], 10, str(row['Violations']), 1, 0, 'C')
    pdf.cell(col_widths[3], 10, str(row['Compliance Rate (%)']), 1, 0, 'C')
    pdf.cell(col_widths[4], 10, pass_fail_text, 1, 0, 'C') # Use cleaned text
    pdf.ln()


pdf.ln(10) # Add space before notes
pdf.set_font("Arial", "B", 12)
pdf.cell(0, 10, "Notes:", ln=True)
pdf.set_font("Arial", size=10)
pdf.cell(0, 5, "- Red boxes indicate missing PPE.", ln=True)
pdf.cell(0, 5, "- Green boxes indicate compliance.", ln=True)
pdf.cell(0, 5, "- Yellow boxes are neutral objects.", ln=True)
pdf.cell(0, 5, "- Thresholds: conf=0.5, iou=0.45", ln=True)


pdf.output(REPORT_PDF)
print(f"📘 PDF report saved at: {REPORT_PDF}")
# Out:
# ✅ Markdown report saved at: /content/drive/MyDrive/Project/Dataset/runs/yolov8_ppe_detection/visual_demo/outputs/RuleTesting/integration_test_report.md
# 📘 PDF report saved at: /content/drive/MyDrive/Project/Dataset/runs/yolov8_ppe_detection/visual_demo/outputs/RuleTesting/integration_test_report.pdf

# %%
# !pip install fpdf
# Out:
# Collecting fpdf
#   Downloading fpdf-1.7.2.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: fpdf
#   Building wheel for fpdf (setup.py) ... done
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40704 sha256=df8b6e1c35ddf2031442894897f93028851059d8128a65e929cfe46979a4f81f
#   Stored in directory: /root/.cache/pip/wheels/6e/62/11/dc73d78e40a218ad52e7451f30166e94491be013a7850b5d75
# Successfully built fpdf
# Installing collected packages: fpdf
# Successfully installed fpdf-1.7.2
